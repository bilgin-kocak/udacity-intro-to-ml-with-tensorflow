# %% [markdown]
# ### Feature Scaling
#
# With any distance based machine learning model (regularized regression methods, neural networks, and now kmeans), you will want to scale your data.
#
# If you have some features that are on completely different scales, this can greatly impact the clusters you get when using K-Means.
#
# In this notebook, you will get to see this first hand.  To begin, let's read in the necessary libraries.

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn import preprocessing as p

# %matplotlib inline

plt.rcParams['figure.figsize'] = (16, 9)
import helpers2 as h
import tests as t


# Create the dataset for the notebook
data = h.simulate_data(200, 2, 4)
df = pd.DataFrame(data)
df.columns = ['height', 'weight']
df['height'] = np.abs(df['height']*100)
df['weight'] = df['weight'] + np.random.normal(50, 10, 200)

# %% [markdown]
# `1.` Next, take a look at the data to get familiar with it.  The dataset has two columns, and it is stored in the **df** variable.  It might be useful to get an idea of the spread in the current data, as well as a visual of the points.

# %%
#Take a look at the data
df.head(10)
df.plot()

# %%
#use this cell if you would like as well
df.shape
plt.scatter(df['height'], df['weight'])

# %% [markdown]
# Now that we've got a dataset, let's look at some options for scaling the data.  As well as how the data might be scaled.  There are two very common types of feature scaling that we should discuss:
#
#
# **I.  MinMaxScaler**
#
# In some cases it is useful to think of your data in terms of the percent they are as compared to the maximum value.  In these cases, you will want to use **MinMaxScaler**.
#
# **II. StandardScaler**
#
# Another very popular type of scaling is to scale data so that it has mean 0 and variance 1.  In these cases, you will want to use **StandardScaler**.
#
# It is probably more appropriate with this data to use **StandardScaler**.  However, to get practice with feature scaling methods in python, we will perform both.
#
# `2.` First let's fit the **StandardScaler** transformation to this dataset.  I will do this one so you can see how to apply preprocessing in sklearn.

# %%
df_ss = p.StandardScaler().fit_transform(df) # Fit and transform the data

# %%
df_ss
# Out:
# array([[ 0.32815009,  1.12734987],
#        [-0.23069775,  0.89916582],
#        [ 1.28002343, -0.26666155],
#        [ 1.86287266,  1.72591206],
#        [ 0.71919792, -1.17697806],
#        [ 0.17660848, -1.10825786],
#        [-0.50730839, -0.55710208],
#        [ 1.46626058,  1.47502648],
#        [-0.53665544,  0.57550591],
#        [ 0.14999227, -0.33301297],
#        [ 0.8562259 , -1.83158859],
#        [-0.33689058, -0.05240318],
#        [ 0.01041941, -0.45457291],
#        [ 0.67698073, -0.81896432],
#        [ 1.3020229 ,  0.22398977],
#        [ 0.81647098, -0.74440698],
#        [-1.26489925,  1.67477581],
#        [ 1.60881585, -0.57567297],
#        [ 0.20138376, -0.84421479],
#        [-0.16385425, -0.16286311],
#        [-0.38148919, -1.21287316],
#        [ 0.67275166, -0.30384249],
#        [ 1.14405103,  1.44843949],
#        [-1.32154201, -0.58951245],
#        [ 0.99822708,  1.45830726],
#        [-1.0193475 ,  0.86139131],
#        [-0.82690773,  0.65110189],
#        [ 0.5415713 , -0.78979661],
#        [-1.37891426,  0.41871936],
#        [-0.93133848,  0.38303803],
#        [ 1.09671473, -1.32260697],
#        [-0.45963163, -2.87294726],
#        [ 1.97046443, -0.25758041],
#        [ 1.610146  , -0.96940917],
#        [-1.44083154,  0.94125572],
#        [-0.38877189,  0.1697378 ],
#        [ 1.10743093, -0.32602987],
#        [-0.19100057, -0.00835855],
#        [ 1.17561288, -0.32178659],
#        [-1.33137873, -1.45083516],
#        [ 0.96719327, -0.83073905],
#        [-0.96593867,  2.1774463 ],
#        [ 0.8783808 , -1.81340667],
#        [-0.18268715, -0.754716  ],
#        [ 1.60719225,  0.93279074],
#        [-0.17524634, -0.83483602],
#        [-0.79030374, -1.04770295],
#        [ 0.45162247, -0.55758207],
#        [-0.98846037,  0.2797407 ],
#        [-1.66571928,  0.43695398],
#        [ 0.38614588, -0.097893  ],
#        [-1.07314914, -0.64801169],
#        [ 0.79628223, -0.29184999],
#        [-0.10811992, -0.8031036 ],
#        [-0.6939542 ,  0.98629155],
#        [-1.04987967,  1.26305032],
#        [-0.38590456, -2.08801051],
#        [ 0.58248215, -0.25619853],
#        [-1.00914604,  0.82051102],
#        [-0.91280891,  0.1632743 ],
#        [ 0.88924676,  0.36626647],
#        [-0.80244502, -0.57189676],
#        [ 0.11478283, -0.47166021],
#        [ 1.28277135,  1.54171157],
#        [ 0.92095118,  0.6784415 ],
#        [ 0.39915295, -0.38949998],
#        [-0.86044406,  0.91253027],
#        [-1.62802578, -0.94970126],
#        [ 0.87922196,  0.94782798],
#        [-1.59389588,  0.02374356],
#        [-1.42568564,  1.11200152],
#        [ 1.18408629,  0.51464508],
#        [-0.92553629,  1.16774989],
#        [ 0.74859605,  0.03559751],
#        [ 0.14021264, -0.5174305 ],
#        [ 0.27088906, -1.51991802],
#        [-0.8639305 , -1.38479783],
#        [-1.10355667,  0.71508559],
#        [ 0.27088402, -1.96029469],
#        [-1.09961921,  1.61035686],
#        [-1.28865138,  0.25696708],
#        [-0.34231632,  0.37165926],
#        [ 1.79568415, -2.30485879],
#        [ 1.14346333, -0.61310275],
#        [ 1.23567855, -0.23812353],
#        [ 1.05296898,  0.35231878],
#        [ 1.27292353, -0.07822529],
#        [-1.3294653 ,  1.49349085],
#        [-0.40559469, -0.95223254],
#        [ 1.36341539,  0.9037069 ],
#        [ 0.46145825, -0.77680027],
#        [-0.71958917,  1.32172427],
#        [-1.05868381, -0.70728004],
#        [-0.44331389,  0.05551349],
#        [-0.42394549, -0.76991219],
#        [ 1.56669001, -0.1041376 ],
#        [-0.95346692,  0.62736669],
#        [-0.32754084, -0.5017561 ],
#        [ 0.29979769, -0.76447728],
#        [-1.13496193,  0.00925119],
#        [ 0.74511938, -0.80146738],
#        [ 1.45774708,  1.66381103],
#        [-1.15501227,  1.1596911 ],
#        [ 0.56444023, -0.87101067],
#        [-1.41433434,  0.13245934],
#        [-0.51993354,  1.07283392],
#        [ 1.06423389,  0.14804379],
#        [ 0.60793439, -0.33692794],
#        [ 0.00779441,  1.10399668],
#        [ 1.92227777, -0.58148508],
#        [-0.32372918, -0.47013338],
#        [ 0.27496784, -2.34507909],
#        [-1.4336152 , -0.1969396 ],
#        [ 0.9949021 ,  1.00172563],
#        [-1.07908486,  1.10126523],
#        [ 2.13720463,  0.00544766],
#        [ 0.6859897 ,  1.4746037 ],
#        [-0.59393479,  0.93038141],
#        [-1.10714331,  1.94108752],
#        [-1.24718522,  0.77269292],
#        [ 0.40101122,  0.82593216],
#        [-0.23669324, -1.41828104],
#        [-0.83131154, -0.8175788 ],
#        [ 1.24428078,  0.46624578],
#        [ 1.13632317,  1.33908131],
#        [-0.61047706, -0.17054473],
#        [-1.42859999,  0.14552042],
#        [-0.09899248, -0.7616179 ],
#        [-0.7880074 ,  0.08938919],
#        [-1.71264371,  1.06464383],
#        [ 0.09269949, -1.08807455],
#        [ 0.48844179, -0.2490713 ],
#        [-1.88908078,  0.80387916],
#        [ 1.26510269,  0.90364888],
#        [ 1.61592021, -0.74791385],
#        [-0.03816028, -0.06841393],
#        [ 0.45386404, -2.97435264],
#        [-0.39033354, -1.53994372],
#        [-1.33353697, -0.12981885],
#        [-0.03431975, -0.11263195],
#        [-1.20810972,  0.3111291 ],
#        [-0.88299199, -1.00810629],
#        [ 1.81097408, -0.25140274],
#        [-1.08174866,  0.06215572],
#        [-0.46052123,  0.05074997],
#        [-0.75498003,  0.77478762],
#        [-0.70526563,  0.79244613],
#        [ 0.92690252,  0.08155537],
#        [ 0.43387714, -1.3712487 ],
#        [ 0.65858437, -1.03235082],
#        [-0.84503599,  1.50187471],
#        [ 1.28256714, -1.87296571],
#        [-0.09552465,  1.06034573],
#        [ 1.32154724,  1.12286364],
#        [ 0.79366998, -0.25576159],
#        [ 0.80494041,  0.26549066],
#        [ 1.68342452,  1.4478731 ],
#        [-0.32467597,  0.2991798 ],
#        [-0.2371221 , -0.58924108],
#        [ 0.0410851 ,  1.12973906],
#        [-1.62395873,  1.55167212],
#        [-0.52883369, -0.1706814 ],
#        [-0.2839868 , -0.6708909 ],
#        [ 1.31920109,  1.26182191],
#        [-1.20495894, -0.07905768],
#        [ 0.24821575, -0.85364909],
#        [-0.3102565 , -1.45619148],
#        [-0.74716918,  0.31012208],
#        [ 0.36589425, -1.00141964],
#        [-0.31690631,  0.11353735],
#        [ 0.75640987,  0.68489624],
#        [-1.29620601,  0.86933446],
#        [ 0.77032029, -0.01718299],
#        [ 0.33503399,  0.3029999 ],
#        [ 0.03468247,  1.84531309],
#        [-0.10509854, -2.7862414 ],
#        [-0.40477411, -0.68407053],
#        [-1.05031317, -0.22239232],
#        [-1.22865963,  0.27466696],
#        [ 0.99178756, -0.25226187],
#        [-1.10601526,  0.98816655],
#        [ 0.80166498, -0.44631804],
#        [ 1.23540247,  1.12535962],
#        [ 1.02170328, -0.59896907],
#        [ 0.93999103,  0.40327054],
#        [-1.89405151,  0.37561022],
#        [-0.21735172,  0.15358569],
#        [-0.35892405,  0.03074127],
#        [-0.77296213, -0.0255915 ],
#        [-1.27958745,  0.03806274],
#        [-1.44092913,  0.23239766],
#        [ 0.77643478, -0.38997218],
#        [ 1.63974537,  0.2084582 ],
#        [ 1.58320666,  0.88362836],
#        [-1.39234999, -0.48789901],
#        [ 1.14884546,  0.65643661],
#        [ 0.33643568, -0.43141771],
#        [-1.93517981,  2.71714569],
#        [ 0.67152841, -1.77496634],
#        [-0.82487566,  1.17843988]])

# %%
df_ss = pd.DataFrame(df_ss) #create a dataframe
df_ss.columns = ['height', 'weight'] #add column names again

plt.scatter(df_ss['height'], df_ss['weight']); # create a plot

# %% [markdown]
# `3.` Now it's your turn.  Try fitting the **MinMaxScaler** transformation to this dataset. You should be able to use the previous example to assist.

# %%
df_mms = p.MinMaxScaler().fit_transform(df)# fit and transform

# %%
df_mms = pd.DataFrame(df_mms)#create a dataframe
df_mms.columns = ['height', 'weight'] #change the column names
#plot the data
plt.scatter(df_mms['height'], df_mms['weight'])

# %% [markdown]
# `4.`  Now let's take a look at how kmeans divides the dataset into different groups for each of the different scalings of the data.  Did you end up with different clusters when the data was scaled differently?

# %%
def fit_kmeans(data, centers):
    '''
    INPUT:
        data = the dataset you would like to fit kmeans to (dataframe)
        centers = the number of centroids (int)
    OUTPUT:
        labels - the labels for each datapoint to which group it belongs (nparray)
    
    '''
    kmeans = KMeans(centers)
    labels = kmeans.fit_predict(data)
    return labels

labels = fit_kmeans(df, 10) #fit kmeans to get the labels
    
# Plot the original data with clusters
plt.scatter(df['height'], df['weight'], c=labels, cmap='Set1');

# %%
#plot each of the scaled datasets
labels = fit_kmeans(df_ss, 10) #fit kmeans to get the labels
    
# Plot the original data with clusters
plt.scatter(df_ss['height'], df_ss['weight'], c=labels, cmap='Set1');

# %%
#another plot of the other scaled dataset
labels = fit_kmeans(df_mms, 10) #fit kmeans to get the labels
    
# Plot the original data with clusters
plt.scatter(df_mms['height'], df_mms['weight'], c=labels, cmap='Set1');

# %% [markdown]
# Write your response here!

# %%
# !tar cvfz allfiles.tar.gz *
# Out:
# C18_FeatScalingEx_01.png
# Changing K - Solution.ipynb
# Changing K.ipynb
# Feature Scaling - Solution.ipynb
# Feature Scaling Example - Solution.ipynb
# Feature Scaling Example.ipynb
# Feature Scaling.ipynb
# Feature_Scaling-zh.ipynb
# Feature_Scaling_Example-zh.ipynb
# Identifying_Clusters.ipynb
# Identifying_Clusters_Solution.ipynb
# UL1_Clustering_Storyboard_Assets.ipynb
# UL6_PCA_Storyboard_Assets.ipynb
# __pycache__/
# __pycache__/helper_functions.cpython-36.pyc
# __pycache__/test_file.cpython-36.pyc
# __pycache__/tests.cpython-36.pyc
# __pycache__/helpers2.cpython-36.pyc
# __pycache__/tests2.cpython-36.pyc
# giphy.gif
# helper_functions.py
# helpers2.py
# images/
# images/C16_IsThatOptimal_03a.png
# images/C03_TypesOfUL_02.png
# images/C03_TypesOfUL_09.png
# images/C16_IsThatOptimal_01.png
# images/C16_IsThatOptimal_03d.png
# images/C17_FeatureScaling_03.png
# images/C18_FeatScalingEx_05.png
# images/C13_HowKMeansWorks_07.png
# images/C13_HowKMeansWorks_04.png
# images/C18_FeatScalingEx_02.png
# images/C16_IsThatOptimal_03c.png
# images/C03_TypesOfUL_07.png
# images/C08_ElbowMethod_04.png
# images/C17_FeatureScaling_04.png
# images/C03_TypesOfUL_06.png
# images/C03_TypesOfUL_01.png
# images/C08_ElbowMethod_06a.png
# images/C13_HowKMeansWorks_08.png
# images/C18_FeatScalingEx_04.png
# images/C08_ElbowMethod_02.png
# images/C03_TypesOfUL_05.png
# images/C08_ElbowMethod_01.png
# images/C18_FeatScalingEx_01.png
# images/C08_ElbowMethod_03.png
# images/C07_ChangingK_03.png
# images/C17_FeatureScaling_01.png
# images/C05_kmeans_00.png
# images/C16_IsThatOptimal_03b.png
# images/C17_FeatureScaling_05a.png
# images/C07_ChangingK_05.png
# images/C16_IsThatOptimal_02c.png
# images/C08_ElbowMethod_07.png
# images/C05_kmeans_01.png
# images/C03_TypesOfUL_04.png
# images/C17_FeatureScaling_06a.png
# images/C16_IsThatOptimal_02b.png
# images/C07_ChangingK_02.png
# images/C13_HowKMeansWorks_05.png
# images/C13_HowKMeansWorks_09.png
# images/C16_IsThatOptimal_02d.png
# images/C07_ChangingK_01.png
# images/C13_HowKMeansWorks_01.png
# images/C07_ChangingK_04.png
# images/C03_TypesOfUL_08.png
# images/C17_FeatureScaling_02.png
# images/C16_IsThatOptimal_02a.png
# images/C03_TypesOfUL_03.png
# images/C13_HowKMeansWorks_03.png
# test_file.py
# tests.py
# tests2.py
